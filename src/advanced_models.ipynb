# %% [markdown]
# # Applying three advanced modeling techniques to the cleaned graduate student data, each answering three research questions
#
# 1. What predicts employment in industry versus academia? (logistic regression)
# 2. Are there latent student profiles? (K means clustering)
# 3. What factors accelerate or dealy time-to-degree? (survival analysis)
#
# Outputs:
# 1. reports/figures/model_*.png for publication ready charts
# 2. data/processed/model_results.json for coefficients and cluster assignments
#
# GIT Commits:
# 1. Logistic regression + confusion matrix
# 2. K Means clustering + profile chart
# 3. Survival analsyis (Kaplan-Meier)
# 4. Export model_results.josn
